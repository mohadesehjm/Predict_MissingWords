# %%
cd !pip install transformers

# %%
import numpy as np
import pandas as pd
from transformers import BertTokenizer, BertForMaskedLM
from torch.nn import functional as F
import torch

# %%
import nltk
nltk.download('punkt')
nltk.download('averaged_perceptron_tagger')

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
dataframe = pd.read_csv('/content/drive/MyDrive/df_5000.csv')

# %%
df = dataframe[:30]

# %%
split_arr = []
for i in range(30):
  text = df['QUESTION'][i]
  split_arr.append(text.split("[BLANK]"))

df_split = pd.DataFrame(split_arr,columns=['split1','split2'])

# %%
df = pd.concat([df,df_split],axis=1)
df = df[['QUESTION','ANSWER','split1','split2']]

# %%
df
# Out:
#                                              QUESTION  ...                                             split2
# 0   Increased content consumption on mobile device...  ...   reached 33% of total online video plays in th...
# 1   National Australia Bank's earnings prospects w...  ...   a weakness in consumer banking. Market income...
# 2   The success of TransCanada's $15 billion claim...  ...   the denial. Most NAFTA disputes settle for an...
# 3   German carmakers may continue to lead factory ...  ...   at full capacity last year as production fell...
# 4   New Cotai resorts have helped fuel citywide re...  ...   guests and revenue volatility as recent cityw...
# 5   The combination of higher interest rates and p...  ...   Chubb Corp. and boosted the acquired portfoli...
# 6   Saudi Arabia baby food sales will surge 11% a ...  ...   up implementation of policies aimed at boosti...
# 7   Nortel Networks Inc. is likely to request by J...  ...   such a request. The 3rd Circuit now must deci...
# 8   Makers of brand-name drugs and biologics will ...  ...   multiple Obamacare-imposed taxes, including t...
# 9   Two California owners of the shuttered San Ono...  ...   defective steam generators, was held liable b...
# 10  Despite President Donald Trump's aim of suppor...  ...   a future for fossil fuels among cleaner energ...
# 11  The resolution authorizing November's referend...  ...   licenses assigned. Through August, Resorts Wo...
# 12  Consensus for Acadia's Nuplazid looks like a h...  ...   concerns over Nuplazid's safety profile, and ...
# 13  Shire must file its response by Oct. 23 to int...  ...   to methods of treating attention deficit hype...
# 14  While Amgen defended Enbrel missing sales esti...  ...   pressure. These may continue to drag volumes ...
# 15  A recovering corn-to-sugar ratio bodes well fo...  ...   in 2016. In the prior cases, the average incr...
# 16  Language in recent Federal Reserve bank deal b...  ...                     M&A activity in the near term.
# 17  SoftBank Corp.'s robust cash flow may still be...  ...   mobile phone bills, rising industry competiti...
# 18  Republican Donald Trump's election as U.S. pre...  ...   it a "disgrace" and promising to renegotiate ...
# 19  Sweden's decision to cut its main repo rate by...  ...  . Banks have defended revenue by chasing fees ...
# 20  On top of the Department of Justice's RMBS tas...  ...   suits by New York and New Jersey in addition ...
# 21  New U.S. single-family home sales may rise 7.5...  ...   the fastest sales pace since 2007. Since bott...
# 22  Most of the 134 deals announced by European fo...  ...  . Companies are selling low-growth, non-strate...
# 23  Bond traders will have more time to adjust to ...  ...   upon in 4Q provide for a four-year phase-in p...
# 24  Set-top boxes maintain a strategic role with p...  ...   to deliver premium services, such as 4K Video...
# 25  Tesla's announcement that it will only source ...  ...   rare earths refineries in Malaysia and China,...
# 26  More attractive financing terms from lower len...  ...   financing rates further. In April, RBI requir...
# 27  A combination of findings from the Bank of Eng...  ...   to the impact of a global slowdown, and poten...
# 28  North American heavy-truck declines this year ...  ...   a 35% reduction in Class 8 production to abou...
# 29  Highway awards in the U.S. dropped 14.1% in Ju...  ...   in 2010-14. In March-June 2015, a few states ...
#
# [30 rows x 4 columns]

# %%
tokenizer = BertTokenizer.from_pretrained('bert-base-uncased')
model = BertForMaskedLM.from_pretrained('bert-base-uncased',return_dict = True)

# %%
labels = []
for i in range(30):
  labels_one_sentence = []
  text = df['split1'][i] + tokenizer.mask_token + df['split2'][i]

  input = tokenizer.encode_plus(text, return_tensors = "pt")
  mask_index = torch.where(input["input_ids"][0] == tokenizer.mask_token_id)


  output = model(**input)
  logits = output.logits

  softmax = F.softmax(logits, dim = -1)
  mask_word = softmax[0, mask_index, :]

  top_5 = torch.topk(mask_word, 5, dim = 1)[1][0]
  for token in top_5:
    word = tokenizer.decode([token])
    labels_one_sentence.append(word)

  labels.append(labels_one_sentence)

# %%
df_label = pd.DataFrame(labels)

# %%
df_answer = pd.concat([df['ANSWER'],df_label],axis=1)
df_answer
# Out:
#         ANSWER             0           1             2            3           4
# 0      viewing       devices     content        videos        games       users
# 1   offsetting       despite         but           and   indicating     showing
# 2    overturns       accepts        wins       rejects     disputes  challenges
# 3          ran           was        were        worked     remained       stood
# 4      attract           its     attract           the  accommodate       cater
# 5   purchasing     acquiring  purchasing        buying  acquisition    creating
# 6        speed         speed       drive          keep         hold      speeds
# 7       denied        denied    rejected       refused         made     granted
# 8      delayed       removed  eliminated     increased      reduced    repealed
# 9     supplied  manufactured    produced  manufactures        built   installed
# 10      enable       provide      create        enable       ensure     promote
# 11      gaming            no         the           all         with        then
# 12     sparked        raised   expressed      reported       raises       cited
# 13    directed       related    relating      relevant   applicable     applied
# 14    applying         under  increasing      building      causing    creating
# 15     reached             %     percent         times       points       years
# 16       drive      increase      reduce      restrict       affect     require
# 17       lower        reduce       cover           cut          pay        save
# 18     calling       calling    labeling     declaring     branding      called
# 19      suffer          fall        rise       decline         grow        drop
# 20   defending        facing    fighting        filing     battling     seeking
# 21      marked           was          is    represents       marked       marks
# 22    complete         occur       close          open       happen        date
# 23      agreed        agreed  elaborated       touched     expanded    improved
# 24  positioned          used        able      utilized    available   developed
# 25     opposed        closed      banned     condemned    protested    targeted
# 26        ease      increase       boost         raise       reduce     improve
# 27     shifted      shifting     shifted         shift        given      shifts
# 28       drive         cause        mean        prompt        force     produce
# 29        seen      achieved     awarded      received       earned    attained

# %%
df_test = pd.read_csv('/content/drive/MyDrive/Tdf_5000.csv')

# %%
split_arr = []
for i in range(30):
  text = df_test['QUESTION'][i]
  split_arr.append(text.split("[BLANK]"))

split_arr
df_T = df_test.iloc[:30,:]
df_split = pd.DataFrame(split_arr,columns=['split1','split2'])
df_T = pd.concat([df_T,df_split],axis=1)
df_T = df_T[['QUESTION','ANSWER','split1','split2']]
df_T
# Out:
#                                              QUESTION  ...                                             split2
# 0   While construction has begun on the Nord Strea...  ...   the necessary approvals. Nord Stream 2 is als...
# 1   A case against 47 people, including OMV execut...  ...   on to the buyer. Yet, the allegations could a...
# 2   Property insurers are positioning themselves t...  ...   to an unsustainable system. Modest reforms pr...
# 3   Low-cost European airlines averaged 9% capacit...  ...   higher yields. EasyJet added only 2.5%, compa...
# 4   Some of the junket operators integral to Macau...  ...   42% in the first quarter. With close relation...
# 5   Recovering state budgets are supporting road-r...  ...   by pavement spending, up 8.5%. Pavement const...
# 6   An increase in the number of U.S. hotel rooms ...  ...   this decline first, since expansion there has...
# 7   BlackRock, Prudential Financial and other mort...  ...   the $98 billion lawsuit against the bank in i...
# 8   Legislation that would give the U.S. Departmen...  ...   either chamber of Congress, this measure favo...
# 9   Neither side of the legal challenge to the EPA...  ...   to seeing the process through to the end. Law...
# 10  Daimler's modest 2017 guidance, restrained by ...  ...   the Stoxx auto index in 2016, yet is unlikely...
# 11  Goldman Sachs has gained the lead among equity...  ...   No. 1 or No. 2 since 2001, lost share and has...
# 12  New regulation, while a key culprit, isn't the...  ...   25% of demand for new drivers will come from ...
# 13  KKR's fundraising increased in 2015-17 followi...  ...   deployments, given elevated levels of dry pow...
# 14  The U.S. Citizenship and Immigration Services ...  ...   applications in May, meaning the winning cont...
# 15  Agricultural chemical stocks correlate with cr...  ...   on farmers' incentive to spend on each produc...
# 16  Food spending makes up more than 40% of Pakist...  ...   down to cheaper products during periods of hi...
# 17  A silver lining in the generally weak PJM grid...  ...   private equity firms, the main plant builders...
# 18  Europe's natural gas consumption will remain u...  ...  . Rising renewable capacity amid decarbonizati...
# 19  Yahoo isn't likely to successfully use a U.S. ...  ...  , and under the May ruling, the plaintiff here...
# 20  Great Wall Motor's WEY SUV is giving it little...  ...   showrooms last spring when it was cannibalizi...
# 21  Gazprom's ability to maintain and expand its d...  ...   a threat. Gazprom Neft's oil and gas output w...
# 22  Steel Dynamics Inc., is the second-largest dom...  ...   with steel scrap, which it then melts, using ...
# 23  Rapidly increasing actual and alternative supp...  ...   every day. Yet in the aftermath of fears of "...
# 24  Of all U.S. banks easing commercial and indust...  ...   by 34% of large and 41% of small banks, down ...
# 25  Relative spot trucking demand in North America...  ...   to several factors, including difficult year-...
# 26  AbbVie's Venclexta may find a role in treating...  ...   an earlier role, given practice-changing data...
# 27  MetLife is seeking to extend beyond July 11 a ...  ...   by the court, an abeyance of the case while t...
# 28  Dominion received Federal Energy Regulatory Co...  ...   $3.4 billion to $3.8 billion cost and capacit...
# 29  Amazon.com's entry to Australia could upend th...  ...   mall retail sales, limiting landlords' abilit...
#
# [30 rows x 4 columns]

# %%
labels = []
for i in range(30):
  labels_one_sentence = []
  text = df_T['split1'][i] + tokenizer.mask_token + df_T['split2'][i]

  input = tokenizer.encode_plus(text, return_tensors = "pt")
  mask_index = torch.where(input["input_ids"][0] == tokenizer.mask_token_id)


  output = model(**input)
  logits = output.logits

  softmax = F.softmax(logits, dim = -1)
  mask_word = softmax[0, mask_index, :]

  top_5 = torch.topk(mask_word, 5, dim = 1)[1][0]
  for token in top_5:
    word = tokenizer.decode([token])
    labels_one_sentence.append(word)

  labels.append(labels_one_sentence)

# %%
df_label = pd.DataFrame(labels)

# %%
df_answer = pd.concat([df_T['ANSWER'],df_label],axis=1)
df_answer
# Out:
#           ANSWER           0            1            2           3            4
# 0          grant      obtain        issue          get     receive         give
# 1         passed      passed      passing         pass        sold       passes
# 2           tied     exposed   vulnerable    connected   committed  susceptible
# 3         garner     achieve      provide      deliver       offer      produce
# 4        plunged        rose    increased         grew        fell      dropped
# 5            led    followed  accompanied       backed       aided    supported
# 6     experience         see   experience       notice        face         have
# 7      narrowing          in       ending   dismissing   regarding       ruling
# 8       controls    controls           in         wins   dominates        leads
# 9      committed   committed    dedicated   committing     devoted        close
# 10        lagged     entered       topped          won      joined       exited
# 11        ranked      ranked       either           at          as      ranking
# 12     estimates   estimates    estimated         says      claims      reports
# 13  accelerating  increasing    expanding      growing  developing  considering
# 14     accepting  processing    accepting    receiving    handling    processed
# 15        depend      depend      depends         rely    depended    depending
# 16         trade        slow       settle         move        turn          cut
# 17      suggests         the         year        meant       means        night
# 18          fall    increase       double         rise    decrease       triple
# 19       proceed     proceed      succeed     continue       occur        arise
# 20           hit         hit        enter        reach       leave         make
# 21        become        pose           be       remain     present       become
# 22        starts       works       starts     produces      begins       trades
# 23      consumed    produced     consumed         sold     flowing    delivered
# 24         cited       cited     reported    expressed       noted        shown
# 25    attributed  attributed          due      related      traced     ascribed
# 26       finding     finding  considering  identifying          in      playing
# 27       granted     granted       denied     approved    rejected       upheld
# 28     estimated   estimated    projected     expected    combined  anticipated
# 29      shopping    shopping        strip     existing      retail          the

# %% [markdown]
# Make level 1-6 : 4.37min

# %%
input = tokenizer.encode_plus("rely")
input.input_ids[1]
# Out:
# 11160

# %%
questions = ['' for i in range(30)]
answers1 = [[] for i in range(30)]
labels1 = [[] for i in range(30)]
answers2 = [[] for i in range(30)]
labels2 = [[] for i in range(30)]
answers3 = [[] for i in range(30)]
labels3 = [[] for i in range(30)]
answers4 = [[] for i in range(30)]
labels4 = [[] for i in range(30)]
answers5 = [[] for i in range(30)]
labels5 = [[] for i in range(30)]
answers6 = [[] for i in range(30)]
labels6 = [[] for i in range(30)]
for j in range(30):
  questions[j] = df['QUESTION'][j]
  text = nltk.word_tokenize(questions[j]);
  pos_tagged = nltk.pos_tag(text)
  for ele in pos_tagged:
    
    if(ele[1].startswith('VB')):
      labels_one_sentence1 = []
      labels_one_sentence2 = []
      labels_one_sentence3 = []
      labels_one_sentence4 = []
      labels_one_sentence5 = []
      labels_one_sentence6 = []
      split_text = questions[j].split(ele[0], 1)
      text1 = split_text[0] + tokenizer.mask_token + split_text[1]
       
      input = tokenizer.encode_plus(text1, return_tensors = "pt")
      mask_index = torch.where(input["input_ids"][0] == tokenizer.mask_token_id)

      output = model(**input)
      logits = output.logits

      softmax = F.softmax(logits, dim = -1)
      mask_word = softmax[0, mask_index, :]

      top_10 = torch.topk(mask_word, 30522, dim = 1)[1][0]
      level1 = top_10[1]
      level2 = top_10[1:10]
      level3 = top_10[10:100]
      level4 = top_10[100:1000]
      level5 = top_10[1000:10000]
      level6 = top_10[10000:]
      # level 1
      if tokenizer.encode_plus(ele[0]).input_ids[1] in level1:
        answers1[j].append(ele[0])
        word = tokenizer.decode([level1])
        labels_one_sentence1.append(word)
        labels1[j].append(labels_one_sentence1)
      #  level 2
      elif tokenizer.encode_plus(ele[0]).input_ids[1] in level2:
        answers2[j].append(ele[0])
        for token in level2:
          word = tokenizer.decode([token])
          labels_one_sentence2.append(word)
        labels2[j].append(labels_one_sentence2)
      # level 3 
      elif tokenizer.encode_plus(ele[0]).input_ids[1] in level3:
        answers3[j].append(ele[0])
        for token in level3:
          word = tokenizer.decode([token])
          labels_one_sentence3.append(word)
        labels3[j].append(labels_one_sentence3)
        # level 4 
      elif tokenizer.encode_plus(ele[0]).input_ids[1] in level4:
        answers4[j].append(ele[0])
        for token in level4:
          word = tokenizer.decode([token])
          labels_one_sentence4.append(word)
        labels4[j].append(labels_one_sentence4)
      #  level 5
      elif tokenizer.encode_plus(ele[0]).input_ids[1] in level5:
        answers5[j].append(ele[0])
        for token in level5:
          word = tokenizer.decode([token])
          labels_one_sentence5.append(word)
        labels5[j].append(labels_one_sentence5)
      #  level 6
      elif tokenizer.encode_plus(ele[0]).input_ids[1] in level6:
        answers6[j].append(ele[0])
        for token in level6:
          word = tokenizer.decode([token])
          labels_one_sentence6.append(word)
        labels6[j].append(labels_one_sentence6)

# %%
arr1 = [[] for i in range(30)]

for i in range(30):
  arr1[i].append(questions[i])
  for j in range(len(answers1[i])):
    # print("i j ",i,j,len(answers[i]))
    arr1[i].append(answers1[i][j])
    # print(answers1[i][j])
    arr1[i].append(labels1[i][j])
    # print( "labels " ,labels1[i][j])


arr2 = [[] for i in range(30)]

for i in range(30):
  arr2[i].append(questions[i])
  for j in range(len(answers2[i])):
    arr2[i].append(answers2[i][j])
    arr2[i].append(labels2[i][j])

arr3 = [[] for i in range(30)]

for i in range(30):
  arr3[i].append(questions[i])
  for j in range(len(answers3[i])):
    arr3[i].append(answers3[i][j])
    arr3[i].append(labels3[i][j])

arr4 = [[] for i in range(30)]

for i in range(30):
  arr4[i].append(questions[i])
  for j in range(len(answers4[i])):
    arr4[i].append(answers4[i][j])
    arr4[i].append(labels4[i][j])

arr5 = [[] for i in range(30)]

for i in range(30):
  arr5[i].append(questions[i])
  for j in range(len(answers5[i])):
    arr5[i].append(answers5[i][j])
    arr5[i].append(labels5[i][j])

arr6 = [[] for i in range(30)]

for i in range(30):
  arr6[i].append(questions[i])
  for j in range(len(answers6[i])):
    arr6[i].append(answers6[i][j])
    arr6[i].append(labels6[i][j])

# %%
df_level1 = pd.DataFrame(arr1)
df_level1
# answers1,labels1
# Out:
#                                                     0  ...           4
# 0   Increased content consumption on mobile device...  ...        None
# 1   National Australia Bank's earnings prospects w...  ...        None
# 2   The success of TransCanada's $15 billion claim...  ...   [resolve]
# 3   German carmakers may continue to lead factory ...  ...      [have]
# 4   New Cotai resorts have helped fuel citywide re...  ...        None
# 5   The combination of higher interest rates and p...  ...        None
# 6   Saudi Arabia baby food sales will surge 11% a ...  ...        None
# 7   Nortel Networks Inc. is likely to request by J...  ...        None
# 8   Makers of brand-name drugs and biologics will ...  ...        None
# 9   Two California owners of the shuttered San Ono...  ...        None
# 10  Despite President Donald Trump's aim of suppor...  ...        None
# 11  The resolution authorizing November's referend...  ...        None
# 12  Consensus for Acadia's Nuplazid looks like a h...  ...       [was]
# 13  Shire must file its response by Oct. 23 to int...  ...  [expected]
# 14  While Amgen defended Enbrel missing sales esti...  ...        None
# 15  A recovering corn-to-sugar ratio bodes well fo...  ...        None
# 16  Language in recent Federal Reserve bank deal b...  ...        None
# 17  SoftBank Corp.'s robust cash flow may still be...  ...        None
# 18  Republican Donald Trump's election as U.S. pre...  ...     [scrap]
# 19  Sweden's decision to cut its main repo rate by...  ...        None
# 20  On top of the Department of Justice's RMBS tas...  ...        None
# 21  New U.S. single-family home sales may rise 7.5...  ...        None
# 22  Most of the 134 deals announced by European fo...  ...        None
# 23  Bond traders will have more time to adjust to ...  ...        None
# 24  Set-top boxes maintain a strategic role with p...  ...        None
# 25  Tesla's announcement that it will only source ...  ...        None
# 26  More attractive financing terms from lower len...  ...        None
# 27  A combination of findings from the Bank of Eng...  ...        None
# 28  North American heavy-truck declines this year ...  ...  [expected]
# 29  Highway awards in the U.S. dropped 14.1% in Ju...  ...        None
#
# [30 rows x 5 columns]

# %%
df_level2 = pd.DataFrame(arr2)
df_level2
# Out:
#                                                    0   ...                                                 10
# 0   Increased content consumption on mobile device...  ...                                               None
# 1   National Australia Bank's earnings prospects w...  ...                                               None
# 2   The success of TransCanada's $15 billion claim...  ...                                               None
# 3   German carmakers may continue to lead factory ...  ...                                               None
# 4   New Cotai resorts have helped fuel citywide re...  ...                                               None
# 5   The combination of higher interest rates and p...  ...                                               None
# 6   Saudi Arabia baby food sales will surge 11% a ...  ...                                               None
# 7   Nortel Networks Inc. is likely to request by J...  ...                                               None
# 8   Makers of brand-name drugs and biologics will ...  ...                                               None
# 9   Two California owners of the shuttered San Ono...  ...                                               None
# 10  Despite President Donald Trump's aim of suppor...  ...                                               None
# 11  The resolution authorizing November's referend...  ...                                               None
# 12  Consensus for Acadia's Nuplazid looks like a h...  ...                                               None
# 13  Shire must file its response by Oct. 23 to int...  ...                                               None
# 14  While Amgen defended Enbrel missing sales esti...  ...                                               None
# 15  A recovering corn-to-sugar ratio bodes well fo...  ...                                               None
# 16  Language in recent Federal Reserve bank deal b...  ...                                               None
# 17  SoftBank Corp.'s robust cash flow may still be...  ...                                               None
# 18  Republican Donald Trump's election as U.S. pre...  ...                                               None
# 19  Sweden's decision to cut its main repo rate by...  ...                                               None
# 20  On top of the Department of Justice's RMBS tas...  ...                                               None
# 21  New U.S. single-family home sales may rise 7.5...  ...                                               None
# 22  Most of the 134 deals announced by European fo...  ...                                               None
# 23  Bond traders will have more time to adjust to ...  ...                                               None
# 24  Set-top boxes maintain a strategic role with p...  ...  [stand, go, be, sit, fly, stare, run, play, po...
# 25  Tesla's announcement that it will only source ...  ...                                               None
# 26  More attractive financing terms from lower len...  ...                                               None
# 27  A combination of findings from the Bank of Eng...  ...                                               None
# 28  North American heavy-truck declines this year ...  ...                                               None
# 29  Highway awards in the U.S. dropped 14.1% in Ju...  ...                                               None
#
# [30 rows x 11 columns]

# %%
df_level3 = pd.DataFrame(arr3)
df_level3
# Out:
#                                                    0   ...                                                 10
# 0   Increased content consumption on mobile device...  ...                                               None
# 1   National Australia Bank's earnings prospects w...  ...                                               None
# 2   The success of TransCanada's $15 billion claim...  ...                                               None
# 3   German carmakers may continue to lead factory ...  ...                                               None
# 4   New Cotai resorts have helped fuel citywide re...  ...                                               None
# 5   The combination of higher interest rates and p...  ...                                               None
# 6   Saudi Arabia baby food sales will surge 11% a ...  ...  [have, starting, refuse, returning, unable, tr...
# 7   Nortel Networks Inc. is likely to request by J...  ...                                               None
# 8   Makers of brand-name drugs and biologics will ...  ...                                               None
# 9   Two California owners of the shuttered San Ono...  ...                                               None
# 10  Despite President Donald Trump's aim of suppor...  ...                                               None
# 11  The resolution authorizing November's referend...  ...                                               None
# 12  Consensus for Acadia's Nuplazid looks like a h...  ...  [while, for, however, meaning, where, unless, ...
# 13  Shire must file its response by Oct. 23 to int...  ...                                               None
# 14  While Amgen defended Enbrel missing sales esti...  ...                                               None
# 15  A recovering corn-to-sugar ratio bodes well fo...  ...                                               None
# 16  Language in recent Federal Reserve bank deal b...  ...                                               None
# 17  SoftBank Corp.'s robust cash flow may still be...  ...                                               None
# 18  Republican Donald Trump's election as U.S. pre...  ...                                               None
# 19  Sweden's decision to cut its main repo rate by...  ...                                               None
# 20  On top of the Department of Justice's RMBS tas...  ...                                               None
# 21  New U.S. single-family home sales may rise 7.5...  ...                                               None
# 22  Most of the 134 deals announced by European fo...  ...                                               None
# 23  Bond traders will have more time to adjust to ...  ...                                               None
# 24  Set-top boxes maintain a strategic role with p...  ...                                               None
# 25  Tesla's announcement that it will only source ...  ...                                               None
# 26  More attractive financing terms from lower len...  ...                                               None
# 27  A combination of findings from the Bank of Eng...  ...                                               None
# 28  North American heavy-truck declines this year ...  ...                                               None
# 29  Highway awards in the U.S. dropped 14.1% in Ju...  ...                                               None
#
# [30 rows x 11 columns]

# %%
df_level4 = pd.DataFrame(arr4)
df_level4
# Out:
#                                                    0   ...                                                 10
# 0   Increased content consumption on mobile device...  ...                                               None
# 1   National Australia Bank's earnings prospects w...  ...                                               None
# 2   The success of TransCanada's $15 billion claim...  ...                                               None
# 3   German carmakers may continue to lead factory ...  ...                                               None
# 4   New Cotai resorts have helped fuel citywide re...  ...                                               None
# 5   The combination of higher interest rates and p...  ...                                               None
# 6   Saudi Arabia baby food sales will surge 11% a ...  ...                                               None
# 7   Nortel Networks Inc. is likely to request by J...  ...                                               None
# 8   Makers of brand-name drugs and biologics will ...  ...                                               None
# 9   Two California owners of the shuttered San Ono...  ...                                               None
# 10  Despite President Donald Trump's aim of suppor...  ...                                               None
# 11  The resolution authorizing November's referend...  ...                                               None
# 12  Consensus for Acadia's Nuplazid looks like a h...  ...  [promise, objectives, gains, materials, feedba...
# 13  Shire must file its response by Oct. 23 to int...  ...                                               None
# 14  While Amgen defended Enbrel missing sales esti...  ...  [turn, break, develop, top, help, sink, crash,...
# 15  A recovering corn-to-sugar ratio bodes well fo...  ...                                               None
# 16  Language in recent Federal Reserve bank deal b...  ...                                               None
# 17  SoftBank Corp.'s robust cash flow may still be...  ...                                               None
# 18  Republican Donald Trump's election as U.S. pre...  ...                                               None
# 19  Sweden's decision to cut its main repo rate by...  ...                                               None
# 20  On top of the Department of Justice's RMBS tas...  ...                                               None
# 21  New U.S. single-family home sales may rise 7.5...  ...                                               None
# 22  Most of the 134 deals announced by European fo...  ...                                               None
# 23  Bond traders will have more time to adjust to ...  ...                                               None
# 24  Set-top boxes maintain a strategic role with p...  ...                                               None
# 25  Tesla's announcement that it will only source ...  ...                                               None
# 26  More attractive financing terms from lower len...  ...                                               None
# 27  A combination of findings from the Bank of Eng...  ...                                               None
# 28  North American heavy-truck declines this year ...  ...                                               None
# 29  Highway awards in the U.S. dropped 14.1% in Ju...  ...                                               None
#
# [30 rows x 11 columns]

# %%
df_level5 = pd.DataFrame(arr5)
df_level5
# Out:
#                                                     0  ...                                                  8
# 0   Increased content consumption on mobile device...  ...                                               None
# 1   National Australia Bank's earnings prospects w...  ...                                               None
# 2   The success of TransCanada's $15 billion claim...  ...                                               None
# 3   German carmakers may continue to lead factory ...  ...                                               None
# 4   New Cotai resorts have helped fuel citywide re...  ...                                               None
# 5   The combination of higher interest rates and p...  ...                                               None
# 6   Saudi Arabia baby food sales will surge 11% a ...  ...                                               None
# 7   Nortel Networks Inc. is likely to request by J...  ...                                               None
# 8   Makers of brand-name drugs and biologics will ...  ...                                               None
# 9   Two California owners of the shuttered San Ono...  ...                                               None
# 10  Despite President Donald Trump's aim of suppor...  ...                                               None
# 11  The resolution authorizing November's referend...  ...                                               None
# 12  Consensus for Acadia's Nuplazid looks like a h...  ...                                               None
# 13  Shire must file its response by Oct. 23 to int...  ...                                               None
# 14  While Amgen defended Enbrel missing sales esti...  ...                                               None
# 15  A recovering corn-to-sugar ratio bodes well fo...  ...                                               None
# 16  Language in recent Federal Reserve bank deal b...  ...                                               None
# 17  SoftBank Corp.'s robust cash flow may still be...  ...                                               None
# 18  Republican Donald Trump's election as U.S. pre...  ...                                               None
# 19  Sweden's decision to cut its main repo rate by...  ...  [pit, subject, teach, serve, reserve, curry, t...
# 20  On top of the Department of Justice's RMBS tas...  ...                                               None
# 21  New U.S. single-family home sales may rise 7.5...  ...                                               None
# 22  Most of the 134 deals announced by European fo...  ...                                               None
# 23  Bond traders will have more time to adjust to ...  ...                                               None
# 24  Set-top boxes maintain a strategic role with p...  ...                                               None
# 25  Tesla's announcement that it will only source ...  ...                                               None
# 26  More attractive financing terms from lower len...  ...                                               None
# 27  A combination of findings from the Bank of Eng...  ...                                               None
# 28  North American heavy-truck declines this year ...  ...                                               None
# 29  Highway awards in the U.S. dropped 14.1% in Ju...  ...                                               None
#
# [30 rows x 9 columns]

# %%
df_level6 = pd.DataFrame(arr6)
df_level6
# Out:
#                                                     0  ...                                                  2
# 0   Increased content consumption on mobile device...  ...                                               None
# 1   National Australia Bank's earnings prospects w...  ...                                               None
# 2   The success of TransCanada's $15 billion claim...  ...                                               None
# 3   German carmakers may continue to lead factory ...  ...                                               None
# 4   New Cotai resorts have helped fuel citywide re...  ...                                               None
# 5   The combination of higher interest rates and p...  ...                                               None
# 6   Saudi Arabia baby food sales will surge 11% a ...  ...                                               None
# 7   Nortel Networks Inc. is likely to request by J...  ...                                               None
# 8   Makers of brand-name drugs and biologics will ...  ...                                               None
# 9   Two California owners of the shuttered San Ono...  ...                                               None
# 10  Despite President Donald Trump's aim of suppor...  ...                                               None
# 11  The resolution authorizing November's referend...  ...                                               None
# 12  Consensus for Acadia's Nuplazid looks like a h...  ...                                               None
# 13  Shire must file its response by Oct. 23 to int...  ...                                               None
# 14  While Amgen defended Enbrel missing sales esti...  ...                                               None
# 15  A recovering corn-to-sugar ratio bodes well fo...  ...                                               None
# 16  Language in recent Federal Reserve bank deal b...  ...                                               None
# 17  SoftBank Corp.'s robust cash flow may still be...  ...                                               None
# 18  Republican Donald Trump's election as U.S. pre...  ...  [ramirez, impression, ##ie, mann, 911, complia...
# 19  Sweden's decision to cut its main repo rate by...  ...                                               None
# 20  On top of the Department of Justice's RMBS tas...  ...                                               None
# 21  New U.S. single-family home sales may rise 7.5...  ...                                               None
# 22  Most of the 134 deals announced by European fo...  ...                                               None
# 23  Bond traders will have more time to adjust to ...  ...                                               None
# 24  Set-top boxes maintain a strategic role with p...  ...                                               None
# 25  Tesla's announcement that it will only source ...  ...                                               None
# 26  More attractive financing terms from lower len...  ...                                               None
# 27  A combination of findings from the Bank of Eng...  ...                                               None
# 28  North American heavy-truck declines this year ...  ...                                               None
# 29  Highway awards in the U.S. dropped 14.1% in Ju...  ...  [due, ##lean, get, invoked, yoga, officials, p...
#
# [30 rows x 3 columns]
